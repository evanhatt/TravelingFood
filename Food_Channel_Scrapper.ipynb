# %% [markdown]
# <a href="https://colab.research.google.com/github/evanhatt/TravelingFood/blob/main/Food_Channel_Scrapper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas==1.4.0
#import libraries
import requests
import pandas as pd
import time
# !pip install psycopg2-binary
import psycopg2 as ps
from numpy import e

# %%
#keys
ChANNEL_ID = "UCyEd6QBSgat5kkC6svyjudA"
API_KEY = "AIzaSyDFDfMvzcJD2bd7kURXXM1D1usZKNqDkJA"

# %%
def get_video_details(video_id):

      #collecting view, like, dislike, comment counts
      url_video_stats = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+API_KEY

      response_video_stats = requests.get(url_video_stats).json()

      view_count = response_video_stats['items'][0]['statistics']['viewCount']
      like_count = response_video_stats['items'][0]['statistics']['likeCount']
      comment_count = response_video_stats['items'][0]['statistics']['commentCount']

      return view_count, like_count, comment_count

# %%
def get_videos(df):
    #define an empty list to collect data
    data = []
    #make API call
    pageToken = ""
    url= "https://www.googleapis.com/youtube/v3/search?key="+API_KEY+"&channelId="+ChANNEL_ID+"&part=snippet,id&order=date&maxResults=10000"+pageToken

    response = requests.get(url).json()
    time.sleep(1)

    for video in response['items']:
        if video['id']['kind'] == "youtube#video":
            video_id = video['id']['videoId']
            video_title = video['snippet']['title']
            upload_date = video['snippet']['publishedAt']
            upload_date = str(upload_date).split("T")[0]

            view_count, like_count, comment_count = get_video_details(video_id)
            #save data in the list
            data.append({'video_id':video_id,'video_title':video_title,
                            'upload_date':upload_date,'view_count':view_count,
                            'like_count':like_count,'comment_count':comment_count})

    # create a DataFrame from the list and concatenate
    df = pd.concat([df, pd.DataFrame(data)], ignore_index=True)
    return df

# %%
# build the dataframe
df =pd.DataFrame(columns=["video_id", "video_title","upload_date","view_count","like_count","comment_count"])

df = get_videos(df)

# %%
df.head()
# Out:
#       video_id                                        video_title upload_date  \
# 0  8p_Ad9dCPVU  Island Seafood Paradise!! 🇲🇺 QUEEN OF SEAFOOD ...  2024-10-01
# 1  E3g-zgSmwUs  Street Food in Mauritius - FRIED CHICKEN TIKKA...  2024-09-28
# 2  rLfE_d538VM  Backyard Biryani Paradise!! EXTREME FOOD in Ma...  2024-09-24
# 3  nAF45YzUQ1w  Best STREET FOOD in Syria!! 🇸🇾 31 Syrian Meals...  2024-09-17
# 4  F2PTz6If3sY  Thai Street Food - BEST $5 MEALS in Phuket, Th...  2024-09-10
#
#   view_count like_count comment_count
# 0     114010       4046           172
# 1     414661       8189           508
# 2     686354      11125           578
# 3     360046       6050           497
# 4     734831      11700           502

# %%
# !pip install google-colab
import pandas as pd
from google.colab import files

df.to_excel("ytfood.xlsx")
files.download('ytfood.xlsx') # use the files object from google.colab
# Out:
# ...
#   Using cached jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
# Using cached jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
# ...

# %%
#keys
ChANNEL_ID = "UCcAd5Np7fO8SeejB1FVKcYw"
API_KEY = "AIzaSyDFDfMvzcJD2bd7kURXXM1D1usZKNqDkJA"

# %%
def get_video_details(video_id):

      #collecting view, like, dislike, comment counts
      url_video_stats = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+API_KEY

      response_video_stats = requests.get(url_video_stats).json()

      view_count = response_video_stats['items'][0]['statistics']['viewCount']
      like_count = response_video_stats['items'][0]['statistics']['likeCount']
      comment_count = response_video_stats['items'][0]['statistics']['commentCount']

      return view_count, like_count, comment_count

# %%
def get_videos(df):
    #make API call
    pageToken = ""
    url= "https://www.googleapis.com/youtube/v3/search?key="+API_KEY+"&channelId="+ChANNEL_ID+"&part=snippet,id&order=date&maxResults=10000"+pageToken

    response = requests.get(url).json()
    time.sleep(1)

    for video in response['items']:
        if video['id']['kind'] == "youtube#video":
            video_id = video['id']['videoId']
            video_title = video['snippet']['title']
            upload_date = video['snippet']['publishedAt']
            upload_date = str(upload_date).split("T")[0]

            view_count, like_count, comment_count = get_video_details(video_id)
            #save data in pandas df
            df = df.append({'video_id':video_id,'video_title':video_title,
                            'upload_date':upload_date,'view_count':view_count,
                            'like_count':like_count,'comment_count':comment_count},
                          ignore_index=True)

    return df

# %%
# build the dataframe
df =pd.DataFrame(columns=["video_id", "video_title","upload_date","view_count","like_count","comment_count"])

df = get_videos(df)
# Out:
# <ipython-input-4-cc8b6e68566f>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id,'video_title':video_title,
# <ipython-input-4-cc8b6e68566f>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id,'video_title':video_title,
# <ipython-input-4-cc8b6e68566f>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id,'video_title':video_title,
# <ipython-input-4-cc8b6e68566f>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id,'video_title':video_title,
# ...

# %%
df.head()
# Out:
#       video_id                                        video_title upload_date  \
# 0  WQXmBU3Pv-0  Traveling To The World&#39;s WORST Food Country!!  2024-09-27
# 1  mgAv3NSgyYs     Surviving Ghana!! Africa’s Most EXTREME Food!!  2024-09-20
# 2  Gt8U7ekFCC0  Eating in Africa&#39;s WILDEST Fish Market!! S...  2024-09-13
# 3  hi9fIuoUki4  How Eating Snails Could Save Africa&#39;s Bush...  2024-09-06
# 4  NqGJaobxyWk  Inside Africa’s Billion Dollar Bushmeat Indust...  2024-08-30
#
#   view_count like_count comment_count
# 0    1098963      22933          2178
# 1     973424      11551           732
# 2    2326715      32898          2208
# 3     704453      17505          1158
# 4    1126531      23553          2051

# %%
df.to_excel("ytfoodbandana.xlsx")

# %%
from google.colab import files
files.download('ytfoodbandana.xlsx')

# %% [markdown]
# NOW WE ARE GOING TO EXTRACT THE COUNTRY FROM THE VIDEO TITLE

# %%
import pandas as pd

df = pd.read_excel("/Users/ellievanhattem/Desktop/Tracking food across the world/ytfood (1).xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-71a52f333531> in <cell line: 3>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_excel("/Users/ellievanhattem/Desktop/Tracking food across the world/ytfood (1).xlsx")
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
import pycountry

# Create a dictionary of country names and their key words
countries = {}
for country in pycountry.countries:
    name = country.name
    alpha2 = country.alpha_2
    alpha3 = country.alpha_3
    keywords = [name, alpha2, alpha3]
    countries[name] = keywords

# %%
def extract_location(title):
    for country, keywords in countries.items():
        for keyword in keywords:
            if keyword in title:
                return country
    return "Unknown"

# %%
df['location'] = df['video_title'].apply(extract_location)

# %%
df.to_excel("video_titles_with_location.xlsx")
files.download('ytfood.xlsx')
